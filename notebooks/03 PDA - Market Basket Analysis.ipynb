# %%
# !pip install mlxtend

# %%
#Importing the libraries

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from mlxtend.frequent_patterns import apriori, association_rules

# %%
data = pd.read_csv('../datasets/groceries - groceries.csv')
data.head()
# Out:
#              Item 1               Item 2          Item 3  \
# 0      citrus fruit  semi-finished bread       margarine
# 1    tropical fruit               yogurt          coffee
# 2        whole milk                  NaN             NaN
# 3         pip fruit               yogurt    cream cheese
# 4  other vegetables           whole milk  condensed milk
#
#                      Item 4 Item 5 Item 6 Item 7 Item 8 Item 9 Item 10  ...  \
# 0               ready soups    NaN    NaN    NaN    NaN    NaN     NaN  ...
# 1                       NaN    NaN    NaN    NaN    NaN    NaN     NaN  ...
# 2                       NaN    NaN    NaN    NaN    NaN    NaN     NaN  ...
# 3              meat spreads    NaN    NaN    NaN    NaN    NaN     NaN  ...
# 4  long life bakery product    NaN    NaN    NaN    NaN    NaN     NaN  ...
#
#   Item 23 Item 24 Item 25 Item 26 Item 27 Item 28 Item 29 Item 30 Item 31  \
# 0     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# ...

# %%
# Convert the dataset into a list of lists (each list is a transaction)
transactions = data.astype(str).values.tolist()

# %%
# Create a list of unique items
items = sorted(list(set(item for sublist in transactions for item in sublist if item != 'nan')))

# %%
# Create a DataFrame where each column is an item and each row is a transaction (one-hot encoded)
encoded_data = pd.DataFrame([[item in transaction for item in items] for transaction in transactions], columns=items)

# %%
# Apply the Apriori algorithm to find frequent itemsets
frequent_itemsets = apriori(encoded_data, min_support=0.01, use_colnames=True)

# %%
# Generate association rules from the frequent itemsets
rules = association_rules(frequent_itemsets, metric="lift", min_threshold=1.0)

# %%
# Display the results
from IPython.display import display

print("Frequent Itemsets:")
display(frequent_itemsets.head())
# Out:
# Frequent Itemsets:
#     support         itemsets
# 0  0.033452       (UHT-milk)
# 1  0.017692  (baking powder)
# 2  0.052466           (beef)
# 3  0.033249        (berries)
# 4  0.026029      (beverages)

# %%
print("\nAssociation Rules:")
display(rules.head())
# Out:
# Association Rules:
#           antecedents         consequents  antecedent support  \
# 0  (other vegetables)              (beef)            0.193493
# 1              (beef)  (other vegetables)            0.052466
# 2        (rolls/buns)              (beef)            0.183935
# 3              (beef)        (rolls/buns)            0.052466
# 4   (root vegetables)              (beef)            0.108998
#
#    consequent support   support  confidence      lift  leverage  conviction  \
# 0            0.052466  0.019725    0.101944  1.943066  0.009574    1.055095
# 1            0.193493  0.019725    0.375969  1.943066  0.009574    1.292416
# 2            0.052466  0.013625    0.074074  1.411858  0.003975    1.023337
# 3            0.183935  0.013625    0.259690  1.411858  0.003975    1.102329
# 4            0.052466  0.017387    0.159515  3.040367  0.011668    1.127366
#
#    zhangs_metric
# 0       0.601792
# 1       0.512224
# 2       0.357463
# 3       0.307866
# 4       0.753189
